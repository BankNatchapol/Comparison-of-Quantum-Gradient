# %% [markdown]
# <a href="https://colab.research.google.com/github/BankNatchapol/Comparison-of-Quantum-Gradient/blob/main/discrete_vs_continuous/gradient_comparison_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
#@title File Names
import os 
HOME = "/gdrive/MyDrive/Comparison-of-quantum-gradient"
DIS_ANA = "analytical_comparison_discrete"
DIS_SAM = "sampling_comparison_discrete"
DIS_REAL = "real_comparison_discrete"

CON_ANA = "analytical_comparison_continuous"
CON_SAM = "sampling_comparison_continuous"

LOSS = "loss"
TIME = "time"

FIX_PARAM = "fixed_params"
FIX_EPOCH = "fixed_epochs"

PS = "ps"
LCU = "lcu"
FD = "fd"
QNG = "qng"
QNW = "qnw"

MAXCUT = "maxcut"
CLIQUE = "clique"
BLP = "blp"
KNAPSACK = "knapsack"

def get_path(gradient_type, value, plot_style, gradient, problem=None):
  if gradient_type == "real_comparison_discrete":
    return os.path.join(HOME, gradient_type, value, plot_style, problem, gradient+".csv")
  else:
    return os.path.join(HOME, gradient_type, value, plot_style, gradient+".pk")

# %%
#@title Load Files
import pickle
psl = pickle.load(open(get_path(DIS_ANA, LOSS, FIX_PARAM, PS), 'rb'))
pst = pickle.load(open(get_path(DIS_ANA, TIME, FIX_PARAM, PS), 'rb'))
pslc = pickle.load(open(get_path(DIS_ANA, LOSS, FIX_EPOCH, PS), 'rb'))
pstc = pickle.load(open(get_path(DIS_ANA, TIME, FIX_EPOCH, PS), 'rb'))

lcul = pickle.load(open(get_path(DIS_ANA, LOSS, FIX_PARAM, LCU), 'rb'))
lcut = pickle.load(open(get_path(DIS_ANA, TIME, FIX_PARAM, LCU), 'rb'))
lculc = pickle.load(open(get_path(DIS_ANA, LOSS, FIX_EPOCH, LCU), 'rb'))
lcutc = pickle.load(open(get_path(DIS_ANA, TIME, FIX_EPOCH, LCU), 'rb'))

fdl = pickle.load(open(get_path(DIS_ANA, LOSS, FIX_PARAM, FD), 'rb'))
fdt = pickle.load(open(get_path(DIS_ANA, TIME, FIX_PARAM, FD), 'rb'))
fdlc = pickle.load(open(get_path(DIS_ANA, LOSS, FIX_EPOCH, FD), 'rb'))
fdtc = pickle.load(open(get_path(DIS_ANA, TIME, FIX_EPOCH, FD), 'rb'))

qngl = pickle.load(open(get_path(DIS_ANA, LOSS, FIX_PARAM, QNG), 'rb'))
qngt = pickle.load(open(get_path(DIS_ANA, TIME, FIX_PARAM, QNG), 'rb'))
qnglc = pickle.load(open(get_path(DIS_ANA, LOSS, FIX_EPOCH, QNG), 'rb'))
qngtc = pickle.load(open(get_path(DIS_ANA, TIME, FIX_EPOCH, QNG), 'rb'))

qnwl = pickle.load(open(get_path(DIS_ANA, LOSS, FIX_PARAM, QNW), 'rb'))
qnwt = pickle.load(open(get_path(DIS_ANA, TIME, FIX_PARAM, QNW), 'rb'))
qnwlc = pickle.load(open(get_path(DIS_ANA, LOSS, FIX_EPOCH, QNW), 'rb'))
qnwtc = pickle.load(open(get_path(DIS_ANA, TIME, FIX_EPOCH, QNW), 'rb'))

pslsam = pickle.load(open(get_path(DIS_SAM, LOSS, FIX_PARAM, PS), 'rb'))
pstsam = pickle.load(open(get_path(DIS_SAM, TIME, FIX_PARAM, PS), 'rb'))
pslcsam = pickle.load(open(get_path(DIS_SAM, LOSS, FIX_EPOCH, PS), 'rb'))
pstcsam = pickle.load(open(get_path(DIS_SAM, TIME, FIX_EPOCH, PS), 'rb'))

lculsam = pickle.load(open(get_path(DIS_SAM, LOSS, FIX_PARAM, LCU), 'rb'))
lcutsam = pickle.load(open(get_path(DIS_SAM, TIME, FIX_PARAM, LCU), 'rb'))
lculcsam = pickle.load(open(get_path(DIS_SAM, LOSS, FIX_EPOCH, LCU), 'rb'))
lcutcsam = pickle.load(open(get_path(DIS_SAM, TIME, FIX_EPOCH, LCU), 'rb'))

fdlsam = pickle.load(open(get_path(DIS_SAM, LOSS, FIX_PARAM, FD), 'rb'))
fdtsam = pickle.load(open(get_path(DIS_SAM, TIME, FIX_PARAM, FD), 'rb'))
fdlcsam = pickle.load(open(get_path(DIS_SAM, LOSS, FIX_EPOCH, FD), 'rb'))
fdtcsam = pickle.load(open(get_path(DIS_SAM, TIME, FIX_EPOCH, FD), 'rb'))

qnglsam = pickle.load(open(get_path(DIS_SAM, LOSS, FIX_PARAM, QNG), 'rb'))
qngtsam = pickle.load(open(get_path(DIS_SAM, TIME, FIX_PARAM, QNG), 'rb'))
qnglcsam = pickle.load(open(get_path(DIS_SAM, LOSS, FIX_EPOCH, QNG), 'rb'))
qngtcsam = pickle.load(open(get_path(DIS_SAM, TIME, FIX_EPOCH, QNG), 'rb'))

qnwlsam = pickle.load(open(get_path(DIS_SAM, LOSS, FIX_PARAM, QNW), 'rb'))
qnwtsam = pickle.load(open(get_path(DIS_SAM, TIME, FIX_PARAM, QNW), 'rb'))
qnwlcsam = pickle.load(open(get_path(DIS_SAM, LOSS, FIX_EPOCH, QNW), 'rb'))
qnwtcsam = pickle.load(open(get_path(DIS_SAM, TIME, FIX_EPOCH, QNW), 'rb'))

cvpsl = pickle.load(open(get_path(CON_ANA, LOSS, FIX_PARAM, PS), 'rb'))
cvpst = pickle.load(open(get_path(CON_ANA, TIME, FIX_PARAM, PS), 'rb'))
cvpslc = pickle.load(open(get_path(CON_ANA, LOSS, FIX_EPOCH, PS), 'rb'))
cvpstc = pickle.load(open(get_path(CON_ANA, TIME, FIX_EPOCH, PS), 'rb'))

cvfdl = pickle.load(open(get_path(CON_ANA, LOSS, FIX_PARAM, FD), 'rb'))
cvfdt = pickle.load(open(get_path(CON_ANA, TIME, FIX_PARAM, FD), 'rb'))
cvfdlc = pickle.load(open(get_path(CON_ANA, LOSS, FIX_EPOCH, FD), 'rb'))
cvfdtc = pickle.load(open(get_path(CON_ANA, TIME, FIX_EPOCH, FD), 'rb'))

cvpslsam = pickle.load(open(get_path(CON_SAM, LOSS, FIX_PARAM, PS), 'rb'))
cvpstsam = pickle.load(open(get_path(CON_SAM, TIME, FIX_PARAM, PS), 'rb'))
cvpslcsam = pickle.load(open(get_path(CON_SAM, LOSS, FIX_EPOCH, PS), 'rb'))
cvpstcsam = pickle.load(open(get_path(CON_SAM, TIME, FIX_EPOCH, PS), 'rb'))

cvfdlsam = pickle.load(open(get_path(CON_SAM, LOSS, FIX_PARAM, FD), 'rb'))
cvfdtsam = pickle.load(open(get_path(CON_SAM, TIME, FIX_PARAM, FD), 'rb'))
cvfdlcsam = pickle.load(open(get_path(CON_SAM, LOSS, FIX_EPOCH, FD), 'rb'))
cvfdtcsam = pickle.load(open(get_path(CON_SAM, TIME, FIX_EPOCH, FD), 'rb'))

rpsl_maxcut = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, PS, MAXCUT))
rpst_maxcut = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, PS, MAXCUT))
rpsl_clique = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, PS, CLIQUE))
rpst_clique = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, PS, CLIQUE))
rpsl_blp = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, PS, BLP))
rpst_blp = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, PS, BLP))
rpsl_knapsack = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, PS, KNAPSACK))
rpst_knapsack = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, PS, KNAPSACK))
rpsl = [rpsl_maxcut, rpsl_clique, rpsl_blp, rpsl_knapsack]
rpst = [rpst_maxcut, rpst_clique, rpst_blp, rpst_knapsack]

rlcul_maxcut = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, LCU, MAXCUT))
rlcut_maxcut = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, LCU, MAXCUT))
rlcul_clique = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, LCU, CLIQUE))
rlcut_clique = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, LCU, CLIQUE))
rlcul_blp = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, LCU, BLP))
rlcut_blp = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, LCU, BLP))
rlcul_knapsack = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, LCU, KNAPSACK))
rlcut_knapsack = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, LCU, KNAPSACK))
rlcul = [rlcul_maxcut, rlcul_clique, rlcul_blp, rlcul_knapsack]
rlcut = [rlcut_maxcut, rlcut_clique, rlcut_blp, rlcut_knapsack]

rfdl_maxcut = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, FD, MAXCUT))
rfdt_maxcut = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, FD, MAXCUT))
rfdl_clique = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, FD, CLIQUE))
rfdt_clique = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, FD, CLIQUE))
rfdl_blp = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, FD, BLP))
rfdt_blp = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, FD, BLP))
rfdl_knapsack = pd.read_csv(get_path(DIS_REAL, LOSS, FIX_PARAM, FD, KNAPSACK))
rfdt_knapsack = pd.read_csv(get_path(DIS_REAL, TIME, FIX_PARAM, FD, KNAPSACK))
rfdl = [rfdl_maxcut, rfdl_clique, rfdl_blp, rfdl_knapsack]
rfdt = [rfdt_maxcut, rfdt_clique, rfdt_blp, rfdt_knapsack]

# %% [markdown]
# # **Discrete**

# %% [markdown]
# ## Fixed Params

# %% [markdown]
#  ### Analytical Gradient

# %%
#@title 
from plotly.subplots import make_subplots

row = 2
col = 2
fig = make_subplots(rows=row, cols=col, subplot_titles=("Max-Cut","Clique","Binary Linear Programming", "Knapsack"))
show = True
for i in range(row):
  for j in range(col):
    problemn = i*col+j
    if problemn>0:
      show = False
    dv = pd.DataFrame({"Iteration":range(len(psl[problemn])), "Loss":psl[problemn]})
    dv_fd = pd.DataFrame({"Iteration":range(len(fdl[problemn])), "Loss":fdl[problemn]})
    dv_lcu = pd.DataFrame({"Iteration":range(len(lcul[problemn])), "Loss":lcul[problemn]})
    dv_qng = pd.DataFrame({"Iteration":range(len(qngl[problemn])), "Loss":qngl[problemn]})
    dv_newton = pd.DataFrame({"Iteration":range(len(qnwl[problemn])), "Loss":qnwl[problemn]})

    # dv_cls = pd.DataFrame({"Iteration":range(len(loss_plot_classical)), "Loss":loss_plot_classical})

    fig.add_trace(go.Scatter(x=dv["Iteration"], y=dv["Loss"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_fd["Iteration"], y=dv_fd["Loss"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_lcu["Iteration"], y=dv_lcu["Loss"], mode="lines", name="Discrete LCU", line = dict(width=2), line_color='yellow', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_qng["Iteration"], y=dv_qng["Loss"], mode="lines", name="Discrete QNG", line = dict(width=2), line_color='blue', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_newton["Iteration"], y=dv_newton["Loss"], mode="lines", name="Discrete Newton Gradient", line = dict(width=2), line_color='brown', showlegend = show), row=i+1, col=j+1)

    # fig.add_trace(go.Scatter(x=dv_cls["Iteration"], y=dv_cls["Loss"], mode="lines", name="Classical"))


fig.update_layout(title="Loss Comparison  <br><sup>Fixed the number of parameterized gate (24 gate).</sup>",
                  xaxis_title="Iteration",
                  yaxis_title="Loss", autosize=False,
                  width=1000,
                  height=700)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title 
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pandas as pd
row = 1
col = 1
fig = make_subplots(rows=row, cols=col, subplot_titles=("Binary Linear Programming","Clique","Binary Linear Programming", "Knapsack"))
show = True
problemn = 2
print("Parameter Shift Rule time     : ", round(pst[problemn][-1], 2))
print("Finite Difference time        : ", round(fdt[problemn][-1], 2))
print("LCU time                      : ", round(lcut[problemn][-1], 2))
print("Quantum Natural Gradient time : ", round(qngt[problemn][-1], 2))
print("Quantum Newton Gradient time  : ", round(qnwt[problemn][-1], 2))
dv = pd.DataFrame({"Iteration":range(len(pst[problemn])), "Time":pst[problemn]})
dv_fd = pd.DataFrame({"Iteration":range(len(fdt[problemn])), "Time":fdt[problemn]})
dv_lcu = pd.DataFrame({"Iteration":range(len(lcut[problemn])), "Time":lcut[problemn]})
dv_qng = pd.DataFrame({"Iteration":range(len(qngt[problemn])), "Time":qngt[problemn]})
dv_newton = pd.DataFrame({"Iteration":range(len(qnwt[problemn])), "Time":qnwt[problemn]})
i=0
j=0
fig.add_trace(go.Scatter(x=dv["Iteration"], y=dv["Time"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_fd["Iteration"], y=dv_fd["Time"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_lcu["Iteration"], y=dv_lcu["Time"], mode="lines", name="Discrete LCU", line = dict(width=2), line_color='yellow', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_qng["Iteration"], y=dv_qng["Time"], mode="lines", name="Discrete QNG", line = dict(width=2), line_color='blue', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_newton["Iteration"], y=dv_newton["Time"], mode="lines", name="Discrete Newton Method", line = dict(width=2), line_color='brown', showlegend = show), row=i+1, col=j+1)

fig.update_layout(title="Time Comparison  <br><sup>Fixed the number of parameterized gate (24 gate).</sup>",
                  xaxis_title="Iteration",
                  yaxis_title="Time (Sec)", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# Parameter Shift Rule time     :  142.55
# Finite Difference time        :  142.39
# LCU time                      :  81.1
# Quantum Natural Gradient time :  163.0
# Quantum Newton Gradient time  :  222.25
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Sampling Gradient

# %%
#@title
from plotly.subplots import make_subplots

row = 2
col = 2
fig = make_subplots(rows=row, cols=col, subplot_titles=("Max-Cut","Clique","Binary Linear Programming", "Knapsack"))
show = True
for i in range(row):
  for j in range(col):
    problemn = i*col+j
    if problemn>0:
      show = False
    dv = pd.DataFrame({"Iteration":range(len(pslsam[problemn])), "Loss":pslsam[problemn]})
    dv_fd = pd.DataFrame({"Iteration":range(len(fdlsam[problemn])), "Loss":fdlsam[problemn]})
    dv_lcu = pd.DataFrame({"Iteration":range(len(lculsam[problemn])), "Loss":lculsam[problemn]})
    dv_qng = pd.DataFrame({"Iteration":range(len(qnglsam[problemn])), "Loss":qnglsam[problemn]})
    dv_newton = pd.DataFrame({"Iteration":range(len(qnwlsam[problemn])), "Loss":qnwlsam[problemn]})

    # dv_cls = pd.DataFrame({"Iteration":range(len(loss_plot_classical)), "Loss":loss_plot_classical})

    fig.add_trace(go.Scatter(x=dv["Iteration"], y=dv["Loss"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_fd["Iteration"], y=dv_fd["Loss"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_lcu["Iteration"], y=dv_lcu["Loss"], mode="lines", name="Discrete LCU", line = dict(width=2), line_color='yellow', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_qng["Iteration"], y=dv_qng["Loss"], mode="lines", name="Discrete QNG", line = dict(width=2), line_color='blue', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_newton["Iteration"], y=dv_newton["Loss"], mode="lines", name="Discrete Newton Gradient", line = dict(width=2), line_color='brown', showlegend = show), row=i+1, col=j+1)

    # fig.add_trace(go.Scatter(x=dv_cls["Iteration"], y=dv_cls["Loss"], mode="lines", name="Classical"))


fig.update_layout(title="Loss Comparison  <br><sup>Fixed the number of parameterized gate (24 gate).</sup>",
                  xaxis_title="Iteration",
                  yaxis_title="Loss", autosize=False,
                  width=1000,
                  height=700)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title 
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pandas as pd
row = 1
col = 1
fig = make_subplots(rows=row, cols=col, subplot_titles=("Binary Linear Programming","Clique","Binary Linear Programming", "Knapsack"))
show = True
problemn = 2
print("Parameter Shift Rule time     : ", round(pstsam[problemn][-1], 2))
print("Finite Difference time        : ", round(fdtsam[problemn][-1], 2))
print("LCU time                      : ", round(lcutsam[problemn][-1], 2))
print("Quantum Natural Gradient time : ", round(qngtsam[problemn][-1], 2))
print("Quantum Newton Gradient time  : ", round(qnwtsam[problemn][-1], 2))
dv = pd.DataFrame({"Iteration":range(len(pstsam[problemn])), "Time":pstsam[problemn]})
dv_fd = pd.DataFrame({"Iteration":range(len(fdtsam[problemn])), "Time":fdtsam[problemn]})
dv_lcu = pd.DataFrame({"Iteration":range(len(lcutsam[problemn])), "Time":lcutsam[problemn]})
dv_qng = pd.DataFrame({"Iteration":range(len(qngtsam[problemn])), "Time":qngtsam[problemn]})
dv_newton = pd.DataFrame({"Iteration":range(len(qnwtsam[problemn])), "Time":qnwtsam[problemn]})
i=0
j=0
fig.add_trace(go.Scatter(x=dv["Iteration"], y=dv["Time"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_fd["Iteration"], y=dv_fd["Time"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_lcu["Iteration"], y=dv_lcu["Time"], mode="lines", name="Discrete LCU", line = dict(width=2), line_color='yellow', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_qng["Iteration"], y=dv_qng["Time"], mode="lines", name="Discrete QNG", line = dict(width=2), line_color='blue', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_newton["Iteration"], y=dv_newton["Time"], mode="lines", name="Discrete Newton Method", line = dict(width=2), line_color='brown', showlegend = show), row=i+1, col=j+1)

fig.update_layout(title="Time Comparison  <br><sup>Fixed the number of parameterized gate (24 gate).</sup>",
                  xaxis_title="Iteration",
                  yaxis_title="Time (Sec)", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# Parameter Shift Rule time     :  211.63
# Finite Difference time        :  212.73
# LCU time                      :  171.44
# Quantum Natural Gradient time :  229.91
# Quantum Newton Gradient time  :  291.55
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Analytical vs Sampling time

# %%
#@title
timetable = pd.DataFrame({"Analytical": [round(pst[problemn][-1], 2), 
                                         round(fdt[problemn][-1], 2), 
                                         round(lcut[problemn][-1], 2), 
                                         round(qngt[problemn][-1], 2), 
                                         round(qnwt[problemn][-1], 2)],
                          "Sampling":[round(pstsam[problemn][-1], 2), 
                                      round(fdtsam[problemn][-1], 2), 
                                      round(lcutsam[problemn][-1], 2), 
                                      round(qngtsam[problemn][-1], 2), 
                                      round(qnwtsam[problemn][-1], 2)]})
timetable.index = ["Parameter Shift Rule", "Finite Difference", "LCU", "Quantum Natural Gradient", "Quantum Newton Gradient"]
timetable
# Out:
#                           Analytical  Sampling
# Parameter Shift Rule          142.55    211.63
# Finite Difference             142.39    212.73
# LCU                            81.10    171.44
# Quantum Natural Gradient      163.00    229.91
# Quantum Newton Gradient       222.25    291.55

# %% [markdown]
# ## Fixed Epochs

# %% [markdown]
# ### Analytical Gradient

# %%
#@title 
steps = [2, 4, 6, 8, 10]
x = [step*12 for step in steps]
row = 2
col = 2
fig = make_subplots(rows=row, cols=col, subplot_titles=("Max-Cut","Clique","Binary Linear Programming", "Knapsack"))
show = True
for i in range(row):
  for j in range(col):
    problemn = i*col+j
    if problemn>0:
      show = False
    dv = pd.DataFrame({"#Param Gates":x, "Loss":pslc[problemn]})
    dv_fd = pd.DataFrame({"#Param Gates":x, "Loss":fdlc[problemn]})
    dv_lcu = pd.DataFrame({"#Param Gates":x, "Loss":lculc[problemn]})
    dv_qng = pd.DataFrame({"#Param Gates":x, "Loss":qnglc[problemn]})
    dv_newton = pd.DataFrame({"#Param Gates":x, "Loss":qnwlc[problemn]})

    fig.add_trace(go.Scatter(x=dv["#Param Gates"], y=dv["Loss"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_fd["#Param Gates"], y=dv_fd["Loss"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_lcu["#Param Gates"], y=dv_lcu["Loss"], mode="lines", name="Discrete LCU", line = dict(width=2), line_color='yellow', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_qng["#Param Gates"], y=dv_qng["Loss"], mode="lines", name="Discrete QNG", line = dict(width=2), line_color='blue', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_newton["#Param Gates"], y=dv_newton["Loss"], mode="lines", name="Discrete Newton Gradient", line = dict(width=2), line_color='brown', showlegend = show), row=i+1, col=j+1)


fig.update_layout(title="Loss Comparison  <br><sup>Fixed epochs (10 epochs).</sup>",
                  xaxis_title="The Number of parameterized gate",
                  yaxis_title="Loss", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title 
row = 1
col = 1
fig = make_subplots(rows=row, cols=col, subplot_titles=("Binary Linear Programming","Clique","Binary Linear Programming", "Knapsack"))
show = True
problemn = 2
i = 0
j = 0
print("Parameter Shift Rule time     : ", round(pstc[problemn][-1], 2))
print("Finite Difference time        : ", round(fdtc[problemn][-1], 2))
print("LCU time                      : ", round(lcutc[problemn][-1], 2))
print("Quantum Natural Gradient time : ", round(qngtc[problemn][-1], 2))
print("Quantum Newton Gradient time  : ", round(qnwtc[problemn][-1], 2))
dv = pd.DataFrame({"#Param Gates":x, "Time":pstc[problemn]})
dv_fd = pd.DataFrame({"#Param Gates":x, "Time":fdtc[problemn]})
dv_lcu = pd.DataFrame({"#Param Gates":x, "Loss":lcutc[problemn]})
dv_qng = pd.DataFrame({"#Param Gates":x, "Time":qngtc[problemn]})
dv_newton = pd.DataFrame({"#Param Gates":x, "Time":qnwtc[problemn]})

fig.add_trace(go.Scatter(x=dv["#Param Gates"], y=dv["Time"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_fd["#Param Gates"], y=dv_fd["Time"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_lcu["#Param Gates"], y=dv_lcu["Loss"], mode="lines", name="Discrete LCU", line = dict(width=2), line_color='yellow', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_qng["#Param Gates"], y=dv_qng["Time"], mode="lines", name="Discrete QNG", line = dict(width=2), line_color='blue', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_newton["#Param Gates"], y=dv_newton["Time"], mode="lines", name="Discrete Newton Gradient", line = dict(width=2), line_color='brown', showlegend = show), row=i+1, col=j+1)


fig.update_layout(title="Time Comparison  <br><sup>Fixed epochs (10 epochs).</sup>",
                  xaxis_title="The Number of parameterized gate",
                  yaxis_title="Time (Sec)", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# Parameter Shift Rule time     :  265.92
# Finite Difference time        :  266.52
# LCU time                      :  161.71
# Quantum Natural Gradient time :  314.59
# Quantum Newton Gradient time  :  441.75
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Sampling Gradient

# %%
#@title 
steps = [2, 4, 6, 8, 10]
x = [step*12 for step in steps]
row = 2
col = 2
fig = make_subplots(rows=row, cols=col, subplot_titles=("Max-Cut","Clique","Binary Linear Programming", "Knapsack"))
show = True
for i in range(row):
  for j in range(col):
    problemn = i*col+j
    if problemn>0:
      show = False
    dv = pd.DataFrame({"#Param Gates":x, "Loss":pslcsam[problemn]})
    dv_fd = pd.DataFrame({"#Param Gates":x, "Loss":fdlcsam[problemn]})
    dv_lcu = pd.DataFrame({"#Param Gates":x, "Loss":lculcsam[problemn]})
    dv_qng = pd.DataFrame({"#Param Gates":x, "Loss":qnglcsam[problemn]})
    dv_newton = pd.DataFrame({"#Param Gates":x, "Loss":qnwlcsam[problemn]})

    fig.add_trace(go.Scatter(x=dv["#Param Gates"], y=dv["Loss"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_fd["#Param Gates"], y=dv_fd["Loss"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_lcu["#Param Gates"], y=dv_lcu["Loss"], mode="lines", name="Discrete LCU", line = dict(width=2), line_color='yellow', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_qng["#Param Gates"], y=dv_qng["Loss"], mode="lines", name="Discrete QNG", line = dict(width=2), line_color='blue', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_newton["#Param Gates"], y=dv_newton["Loss"], mode="lines", name="Discrete Newton Gradient", line = dict(width=2), line_color='brown', showlegend = show), row=i+1, col=j+1)


fig.update_layout(title="Loss Comparison  <br><sup>Fixed epochs (10 epochs).</sup>",
                  xaxis_title="The Number of parameterized gate",
                  yaxis_title="Loss", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title 
row = 1
col = 1
fig = make_subplots(rows=row, cols=col, subplot_titles=("Binary Linear Programming","Clique","Binary Linear Programming", "Knapsack"))
show = True
problemn = 2
i = 0
j = 0
print("Parameter Shift Rule time     : ", round(pstcsam[problemn][-1], 2))
print("Finite Difference time        : ", round(fdtcsam[problemn][-1], 2))
print("LCU time                      : ", round(lcutcsam[problemn][-1], 2))
print("Quantum Natural Gradient time : ", round(qngtcsam[problemn][-1], 2))
print("Quantum Newton Gradient time  : ", round(qnwtcsam[problemn][-1], 2))
dv = pd.DataFrame({"#Param Gates":x, "Time":pstcsam[problemn]})
dv_fd = pd.DataFrame({"#Param Gates":x, "Time":fdtcsam[problemn]})
dv_lcu = pd.DataFrame({"#Param Gates":x, "Loss":lcutcsam[problemn]})
dv_qng = pd.DataFrame({"#Param Gates":x, "Time":qngtcsam[problemn]})
dv_newton = pd.DataFrame({"#Param Gates":x, "Time":qnwtcsam[problemn]})

fig.add_trace(go.Scatter(x=dv["#Param Gates"], y=dv["Time"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_fd["#Param Gates"], y=dv_fd["Time"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_lcu["#Param Gates"], y=dv_lcu["Loss"], mode="lines", name="Discrete LCU", line = dict(width=2), line_color='yellow', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_qng["#Param Gates"], y=dv_qng["Time"], mode="lines", name="Discrete QNG", line = dict(width=2), line_color='blue', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_newton["#Param Gates"], y=dv_newton["Time"], mode="lines", name="Discrete Newton Gradient", line = dict(width=2), line_color='brown', showlegend = show), row=i+1, col=j+1)


fig.update_layout(title="Time Comparison  <br><sup>Fixed epochs (10 epochs).</sup>",
                  xaxis_title="The Number of parameterized gate",
                  yaxis_title="Time (Sec)", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# Parameter Shift Rule time     :  505.01
# Finite Difference time        :  506.76
# LCU time                      :  406.34
# Quantum Natural Gradient time :  553.49
# Quantum Newton Gradient time  :  693.95
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Analytical vs Sampling time

# %%
#@title
timetable = pd.DataFrame({"Analytical": [round(pstc[problemn][-1], 2), 
                                         round(fdtc[problemn][-1], 2), 
                                         round(lcutc[problemn][-1], 2), 
                                         round(qngtc[problemn][-1], 2), 
                                         round(qnwtc[problemn][-1], 2)],
                          "Sampling":[round(pstcsam[problemn][-1], 2), 
                                      round(fdtcsam[problemn][-1], 2), 
                                      round(lcutcsam[problemn][-1], 2), 
                                      round(qngtcsam[problemn][-1], 2), 
                                      round(qnwtcsam[problemn][-1], 2)]})
timetable.index = ["Parameter Shift Rule", "Finite Difference", "LCU", "Quantum Natural Gradient", "Quantum Newton Gradient"]
timetable
# Out:
#                           Analytical  Sampling
# Parameter Shift Rule          265.92    505.01
# Finite Difference             266.52    506.76
# LCU                           161.71    406.34
# Quantum Natural Gradient      314.59    553.49
# Quantum Newton Gradient       441.75    693.95

# %% [markdown]
# # **Continuous**

# %% [markdown]
# ## Fixed Params

# %% [markdown]
# ### Analytical Gradient

# %%
#@title 
from plotly.subplots import make_subplots

row = 2
col = 2
fig = make_subplots(rows=row, cols=col, subplot_titles=("Max-Cut","Clique","Binary Linear Programming", "Knapsack"))
show = True
for i in range(row):
  for j in range(col):
    problemn = i*col+j
    if problemn>0:
      show = False
    dv_cv = pd.DataFrame({"Iteration":range(len(cvpsl[problemn])), "Loss":cvpsl[problemn]})
    dv_fd_cv = pd.DataFrame({"Iteration":range(len(cvfdl[problemn])), "Loss":cvfdl[problemn]})

    fig.add_trace(go.Scatter(x=dv_cv["Iteration"], y=dv_cv["Loss"], name="Continuous Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_fd_cv["Iteration"], y=dv_fd_cv["Loss"], mode="lines", name="Continuous Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)


fig.update_layout(title="Loss Comparison  <br><sup>Fixed the number of parameterized gate (24 gate).</sup>",
                  xaxis_title="Iteration",
                  yaxis_title="Loss", autosize=False,
                  width=1000,
                  height=700)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title 
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pandas as pd
row = 1
col = 1
fig = make_subplots(rows=row, cols=col, subplot_titles=("Binary Linear Programming","Clique","Binary Linear Programming", "Knapsack"))
show = True
problemn = 2
print("Parameter Shift Rule time     : ", round(cvpst[problemn][-1], 2))
print("Finite Difference time        : ", round(cvfdt[problemn][-1], 2))

dv = pd.DataFrame({"Iteration":range(len(cvpst[problemn])), "Time":cvpst[problemn]})
dv_fd = pd.DataFrame({"Iteration":range(len(cvfdt[problemn])), "Time":cvfdt[problemn]})
i=0
j=0
fig.add_trace(go.Scatter(x=dv["Iteration"], y=dv["Time"], name="Continuous Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_fd["Iteration"], y=dv_fd["Time"], mode="lines", name="Continuous Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)

fig.update_layout(title="Time Comparison  <br><sup>Fixed the number of parameterized gate (24 gate).</sup>",
                  xaxis_title="Iteration",
                  yaxis_title="Time (Sec)", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# Parameter Shift Rule time     :  151.52
# Finite Difference time        :  143.45
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Sampling Gradient

# %%
#@title 
from plotly.subplots import make_subplots

row = 2
col = 2
fig = make_subplots(rows=row, cols=col, subplot_titles=("Max-Cut","Clique","Binary Linear Programming", "Knapsack"))
show = True
for i in range(row):
  for j in range(col):
    problemn = i*col+j
    if problemn>0:
      show = False
    dv_cv = pd.DataFrame({"Iteration":range(len(cvpslsam[problemn])), "Loss":cvpslsam[problemn]})
    dv_fd_cv = pd.DataFrame({"Iteration":range(len(cvfdlsam[problemn])), "Loss":cvfdlsam[problemn]})

    fig.add_trace(go.Scatter(x=dv_cv["Iteration"], y=dv_cv["Loss"], name="Continuous Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_fd_cv["Iteration"], y=dv_fd_cv["Loss"], mode="lines", name="Continuous Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)


fig.update_layout(title="Loss Comparison  <br><sup>Fixed the number of parameterized gate (24 gate).</sup>",
                  xaxis_title="Iteration",
                  yaxis_title="Loss", autosize=False,
                  width=1000,
                  height=700)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title 
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pandas as pd
row = 1
col = 1
fig = make_subplots(rows=row, cols=col, subplot_titles=("Binary Linear Programming","Clique","Binary Linear Programming", "Knapsack"))
show = True
problemn = 2
print("Parameter Shift Rule time     : ", round(cvpstsam[problemn][-1], 2))
print("Finite Difference time        : ", round(cvfdtsam[problemn][-1], 2))

dv = pd.DataFrame({"Iteration":range(len(cvpstsam[problemn])), "Time":cvpstsam[problemn]})
dv_fd = pd.DataFrame({"Iteration":range(len(cvfdtsam[problemn])), "Time":cvfdtsam[problemn]})
i=0
j=0
fig.add_trace(go.Scatter(x=dv["Iteration"], y=dv["Time"], name="Continuous Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_fd["Iteration"], y=dv_fd["Time"], mode="lines", name="Continuous Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)

fig.update_layout(title="Time Comparison  <br><sup>Fixed the number of parameterized gate (24 gate).</sup>",
                  xaxis_title="Iteration",
                  yaxis_title="Time (Sec)", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# Parameter Shift Rule time     :  168.9
# Finite Difference time        :  169.91
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Analytical vs Sampling

# %%
#@title
timetable = pd.DataFrame({"Analytical": [round(cvpst[problemn][-1], 2), 
                                         round(cvfdt[problemn][-1], 2), 
                                         ],
                          "Sampling":[round(cvpstsam[problemn][-1], 2), 
                                      round(cvfdtsam[problemn][-1], 2), 
                                      ]})
timetable.index = ["Parameter Shift Rule", "Finite Difference"]
timetable
# Out:
#                       Analytical  Sampling
# Parameter Shift Rule      151.52    168.90
# Finite Difference         143.45    169.91

# %% [markdown]
# ## Fixed Epochs

# %% [markdown]
# ### Analytical Gradient

# %%
#@title 
steps = [2, 4, 6, 8, 10]
x = [step*12 for step in steps]
row = 2
col = 2
fig = make_subplots(rows=row, cols=col, subplot_titles=("Max-Cut","Clique","Binary Linear Programming", "Knapsack"))
show = True
for i in range(row):
  for j in range(col):
    problemn = i*col+j
    if problemn>0:
      show = False
    dv = pd.DataFrame({"#Param Gates":x, "Loss":cvpslc[problemn]})
    dv_fd = pd.DataFrame({"#Param Gates":x, "Loss":cvfdlc[problemn]})

    fig.add_trace(go.Scatter(x=dv["#Param Gates"], y=dv["Loss"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_fd["#Param Gates"], y=dv_fd["Loss"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)

fig.update_layout(title="Loss Comparison  <br><sup>Fixed epochs (10 epochs).</sup>",
                  xaxis_title="The Number of parameterized gate",
                  yaxis_title="Loss", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title 
row = 1
col = 1
fig = make_subplots(rows=row, cols=col, subplot_titles=("Binary Linear Programming","Clique","Binary Linear Programming", "Knapsack"))
show = True
problemn = 2
i = 0
j = 0
print("Parameter Shift Rule time     : ", round(pstc[problemn][-1], 2))
print("Finite Difference time        : ", round(fdtc[problemn][-1], 2))

dv = pd.DataFrame({"#Param Gates":x, "Time":cvpstc[problemn]})
dv_fd = pd.DataFrame({"#Param Gates":x, "Time":cvfdtc[problemn]})

fig.add_trace(go.Scatter(x=dv["#Param Gates"], y=dv["Time"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_fd["#Param Gates"], y=dv_fd["Time"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)


fig.update_layout(title="Time Comparison  <br><sup>Fixed epochs (10 epochs).</sup>",
                  xaxis_title="The Number of parameterized gate",
                  yaxis_title="Time (Sec)", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# Parameter Shift Rule time     :  265.92
# Finite Difference time        :  266.52
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Sampling Gradient

# %%
#@title 
steps = [2, 4, 6, 8, 10]
x = [step*12 for step in steps]
row = 2
col = 2
fig = make_subplots(rows=row, cols=col, subplot_titles=("Max-Cut","Clique","Binary Linear Programming", "Knapsack"))
show = True
for i in range(row):
  for j in range(col):
    problemn = i*col+j
    if problemn>0:
      show = False
    dv = pd.DataFrame({"#Param Gates":x, "Loss":cvpslcsam[problemn]})
    dv_fd = pd.DataFrame({"#Param Gates":x, "Loss":cvfdlcsam[problemn]})

    fig.add_trace(go.Scatter(x=dv["#Param Gates"], y=dv["Loss"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
    fig.add_trace(go.Scatter(x=dv_fd["#Param Gates"], y=dv_fd["Loss"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)

fig.update_layout(title="Loss Comparison  <br><sup>Fixed epochs (10 epochs).</sup>",
                  xaxis_title="The Number of parameterized gate",
                  yaxis_title="Loss", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title 
row = 1
col = 1
fig = make_subplots(rows=row, cols=col, subplot_titles=("Binary Linear Programming","Clique","Binary Linear Programming", "Knapsack"))
show = True
problemn = 2
i = 0
j = 0
print("Parameter Shift Rule time     : ", round(cvpstcsam[problemn][-1], 2))
print("Finite Difference time        : ", round(cvfdtcsam[problemn][-1], 2))

dv = pd.DataFrame({"#Param Gates":x, "Time":cvpstcsam[problemn]})
dv_fd = pd.DataFrame({"#Param Gates":x, "Time":cvfdtcsam[problemn]})

fig.add_trace(go.Scatter(x=dv["#Param Gates"], y=dv["Time"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=j+1)
fig.add_trace(go.Scatter(x=dv_fd["#Param Gates"], y=dv_fd["Time"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=j+1)

fig.update_layout(title="Time Comparison  <br><sup>Fixed epochs (10 epochs).</sup>",
                  xaxis_title="The Number of parameterized gate",
                  yaxis_title="Time (Sec)", autosize=False,
                  width=1000,
                  height=700)
fig.show()
# Out:
# Parameter Shift Rule time     :  205.57
# Finite Difference time        :  205.98
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Analytical vs Sampling

# %%
#@title
timetable = pd.DataFrame({"Analytical": [round(cvpstc[problemn][-1], 2), 
                                         round(cvfdtc[problemn][-1], 2), 
                                         ],
                          "Sampling":[round(cvpstcsam[problemn][-1], 2), 
                                      round(cvfdtcsam[problemn][-1], 2), 
                                      ]})
timetable.index = ["Parameter Shift Rule", "Finite Difference"]
timetable
# Out:
#                       Analytical  Sampling
# Parameter Shift Rule      181.95    205.57
# Finite Difference         176.74    205.98

# %% [markdown]
# # **Real**

# %%
#@title 
from plotly.subplots import make_subplots

row = 4
col = 2
fig = make_subplots(rows=row, cols=col, subplot_titles=("Max-Cut Real", "Max-Cut Sim", "Clique Real", "Clique Sim","Binary Linear Programming Real", "Binary Linear Programming Sim", "Knapsack Real", "Knapsack Sim"))
show = True
for i in range(row):
  problemn = i
  if problemn>0:
    show = False
  dv = pd.DataFrame({"Iteration":range(len(rpsl[problemn])), "Loss":rpsl[problemn]["real"]})
  dv_fd = pd.DataFrame({"Iteration":range(len(rfdl[problemn])), "Loss":rfdl[problemn]["real"]})
  dv_lcu = pd.DataFrame({"Iteration":range(len(rlcul[problemn])), "Loss":rlcul[problemn]["real"]})

  fig.add_trace(go.Scatter(x=dv["Iteration"], y=dv["Loss"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = show), row=i+1, col=1)
  fig.add_trace(go.Scatter(x=dv_fd["Iteration"], y=dv_fd["Loss"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = show), row=i+1, col=1)
  fig.add_trace(go.Scatter(x=dv_lcu["Iteration"], y=dv_lcu["Loss"], mode="lines", name="Discrete LCU", line = dict(width=2), line_color='blue', showlegend = show), row=i+1, col=1)

  dv = pd.DataFrame({"Iteration":range(len(rpsl[problemn])), "Loss":rpsl[problemn]["sim"]})
  dv_fd = pd.DataFrame({"Iteration":range(len(rfdl[problemn])), "Loss":rfdl[problemn]["sim"]})
  dv_lcu = pd.DataFrame({"Iteration":range(len(rlcul[problemn])), "Loss":rlcul[problemn]["sim"]})

  fig.add_trace(go.Scatter(x=dv["Iteration"], y=dv["Loss"], name="Discrete Parameter Shift", line = dict(width=2), line_color='red', showlegend = False), row=i+1, col=2)
  fig.add_trace(go.Scatter(x=dv_fd["Iteration"], y=dv_fd["Loss"], mode="lines", name="Discrete Finite Difference", line = dict(width=2), line_color='green', showlegend = False), row=i+1, col=2)
  fig.add_trace(go.Scatter(x=dv_lcu["Iteration"], y=dv_lcu["Loss"], mode="lines", name="Discrete LCU", line = dict(width=2), line_color='blue', showlegend = False), row=i+1, col=2)

fig.update_layout(title="Loss Comparison  <br><sup>Fixed the number of parameterized gate (8 gate).</sup>",
                  xaxis_title="Iteration",
                  yaxis_title="Loss", autosize=False,
                  width=1000,
                  height=1000)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title
timetable = pd.DataFrame({"Real (hours)": [round(rpst[3]["real"].iloc[-1]/3600, 2), 
                                         round(rfdt[3]["real"].iloc[-1]/3600, 2), 
                                         round(rlcut[3]["real"].iloc[-1]/3600, 2), 
                                         ]})
timetable.index = ["Parameter Shift Rule", "Finite Difference", "LCU"]
timetable
# Out:
#                       Real (hours)
# Parameter Shift Rule          2.23
# Finite Difference             2.29
# LCU                           1.06
